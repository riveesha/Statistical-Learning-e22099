# %% [markdown]
# Q01)

# %% [markdown]
# Q1.1

# %%
from IPython.display import display, Math

display(Math(r'''
\text{The probability space is}
'''))

display(Math(r'''
\Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
'''))

display(Math(r'''
\mathfrak F=\mathfrak P(\Omega),
'''))

display(Math(r'''
\text{and the probability measure } P \text{ is defined by}
'''))

display(Math(r'''
P(\{\omega_1\})=0.50,\qquad
P(\{\omega_2\})=0.10,\qquad
P(\{\omega_3\})=0.20,\qquad
P(\{\omega_4\})=0.20.
'''))

display(Math(r'''
\text{Since}
'''))

display(Math(r'''
0.50+0.10+0.20+0.20=1,
'''))

display(Math(r'''
\text{this is a valid probability measure.}
'''))
# Out:
# $\displaystyle
# \text{The probability space is}
# $
# $\displaystyle
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
# $
# $\displaystyle
# \mathfrak F=\mathfrak P(\Omega),
# $
# $\displaystyle
# \text{and the probability measure } P \text{ is defined by}
# $
# $\displaystyle
# P(\{\omega_1\})=0.50,\qquad
# P(\{\omega_2\})=0.10,\qquad
# P(\{\omega_3\})=0.20,\qquad
# P(\{\omega_4\})=0.20.
# $
# $\displaystyle
# \text{Since}
# $
# $\displaystyle
# 0.50+0.10+0.20+0.20=1,
# $
# $\displaystyle
# \text{this is a valid probability measure.}
# $

# %% [markdown]
# Q1.2

# %%
from IPython.display import display, Math

display(Math(r'''
\text{The random variable } Y \text{ is defined by}
'''))

display(Math(r'''
Y(\omega_1)=0,\qquad
Y(\omega_2)=0,\qquad
Y(\omega_3)=1,\qquad
Y(\omega_4)=1.
'''))

display(Math(r'''
\text{Thus the inverse images of the values of } Y \text{ are}
'''))

display(Math(r'''
Y^{-1}(\{0\})=\{\omega_1,\omega_2\},
'''))

display(Math(r'''
\text{and}
'''))

display(Math(r'''
Y^{-1}(\{1\})=\{\omega_3,\omega_4\}.
'''))

display(Math(r'''
\text{Therefore the } \sigma\text{-algebra generated by } Y \text{ is}
'''))

display(Math(r'''
\sigma(Y)=\left\{
\varnothing,
\Omega,
\{\omega_1,\omega_2\},
\{\omega_3,\omega_4\}
\right\}.
'''))
# Out:
# $\displaystyle
# \text{The random variable } Y \text{ is defined by}
# $
# $\displaystyle
# Y(\omega_1)=0,\qquad
# Y(\omega_2)=0,\qquad
# Y(\omega_3)=1,\qquad
# Y(\omega_4)=1.
# $
# $\displaystyle
# \text{Thus the inverse images of the values of } Y \text{ are}
# $
# $\displaystyle
# Y^{-1}(\{0\})=\{\omega_1,\omega_2\},
# $
# $\displaystyle
# \text{and}
# $
# $\displaystyle
# Y^{-1}(\{1\})=\{\omega_3,\omega_4\}.
# $
# $\displaystyle
# \text{Therefore the } \sigma\text{-algebra generated by } Y \text{ is}
# $
# $\displaystyle
# \sigma(Y)=\left\{
# \varnothing,
# \Omega,
# \{\omega_1,\omega_2\},
# \{\omega_3,\omega_4\}
# \right\}.
# $

# %% [markdown]
# Q1.3

# %%
from IPython.display import display, Math

display(Math(r'''
\text{By definition, } E[X\mid Y] \text{ must be } \sigma(Y)\text{-measurable.}
'''))

display(Math(r'''
\text{This means it can depend only on the value of } Y,
\text{ not on the full outcome } \omega.
'''))

display(Math(r'''
\text{That is } E[X\mid Y]=g(Y)
\text{ for some measurable map } g.
'''))

display(Math(r'''
\text{Since } \sigma(Y) \text{ can distinguish only the two sets}
'''))

display(Math(r'''
\{\omega_1,\omega_2\}
\quad \text{and} \quad
\{\omega_3,\omega_4\},
'''))

display(Math(r'''
\text{the random variable } E[X\mid Y]
\text{ must be constant on each of these sets.}
'''))

display(Math(r'''
\text{So we write}
'''))

display(Math(r'''
E[X\mid Y](\omega)=
\begin{cases}
a, & \omega\in\{\omega_1,\omega_2\},\\
b, & \omega\in\{\omega_3,\omega_4\},
\end{cases}
'''))

display(Math(r'''
\text{for some constants } a \text{ and } b \text{ to be determined.}
'''))
# Out:
# $\displaystyle
# \text{By definition, } E[X\mid Y] \text{ must be } \sigma(Y)\text{-measurable.}
# $
# $\displaystyle
# \text{This means it can depend only on the value of } Y,
# \text{ not on the full outcome } \omega.
# $
# $\displaystyle
# \text{That is } E[X\mid Y]=g(Y)
# \text{ for some measurable map } g.
# $
# $\displaystyle
# \text{Since } \sigma(Y) \text{ can distinguish only the two sets}
# $
# $\displaystyle
# \{\omega_1,\omega_2\}
# \quad \text{and} \quad
# \{\omega_3,\omega_4\},
# $
# $\displaystyle
# \text{the random variable } E[X\mid Y]
# \text{ must be constant on each of these sets.}
# $
# $\displaystyle
# \text{So we write}
# $
# $\displaystyle
# E[X\mid Y](\omega)=
# \begin{cases}
# a, & \omega\in\{\omega_1,\omega_2\},\\
# b, & \omega\in\{\omega_3,\omega_4\},
# \end{cases}
# $
# $\displaystyle
# \text{for some constants } a \text{ and } b \text{ to be determined.}
# $

# %% [markdown]
# Q1.4

# %%
from IPython.display import display, Math

display(Math(r'''
\text{To find } a \text{ and } b,\text{ we use the defining property of conditional expectation.}
'''))

display(Math(r'''
\text{On the set } \{\omega_1,\omega_2\},
'''))

display(Math(r'''
\int_{\{\omega_1,\omega_2\}} E[X\mid Y]\,dP
=
\int_{\{\omega_1,\omega_2\}} X\,dP.
'''))

display(Math(r'''
\text{The left-hand side is}
'''))

display(Math(r'''
a\cdot P(\{\omega_1,\omega_2\})
=
a(0.50+0.10)
=
0.60a.
'''))

display(Math(r'''
\text{The right-hand side is}
'''))

display(Math(r'''
0\cdot 0.50 + 1\cdot 0.10 = 0.10.
'''))

display(Math(r'''
\text{So}
'''))

display(Math(r'''
0.60a=0.10,
'''))

display(Math(r'''
\text{hence}
'''))

display(Math(r'''
a=\frac{0.10}{0.60}=\frac{1}{6}.
'''))

display(Math(r'''
\text{On the set } \{\omega_3,\omega_4\},
'''))

display(Math(r'''
\int_{\{\omega_3,\omega_4\}} E[X\mid Y]\,dP
=
\int_{\{\omega_3,\omega_4\}} X\,dP.
'''))

display(Math(r'''
\text{The left-hand side is}
'''))

display(Math(r'''
b\cdot P(\{\omega_3,\omega_4\})
=
b(0.20+0.20)
=
0.40b.
'''))

display(Math(r'''
\text{The right-hand side is}
'''))

display(Math(r'''
0\cdot 0.20 + 1\cdot 0.20 = 0.20.
'''))

display(Math(r'''
\text{So}
'''))

display(Math(r'''
0.40b=0.20,
'''))

display(Math(r'''
\text{hence}
'''))

display(Math(r'''
b=\frac{0.20}{0.40}=\frac{1}{2}.
'''))

display(Math(r'''
\text{Therefore}
'''))

display(Math(r'''
E[X\mid Y](\omega)=
\begin{cases}
\dfrac{1}{6}, & \omega\in\{\omega_1,\omega_2\},\\
\dfrac{1}{2}, & \omega\in\{\omega_3,\omega_4\}.
\end{cases}
'''))

display(Math(r'''
\text{Equivalently, as a function of } Y,
'''))

display(Math(r'''
E[X\mid Y]
=
\frac{1}{6}\mathbb{1}_{\{Y=0\}}
+
\frac{1}{2}\mathbb{1}_{\{Y=1\}}
=
\begin{cases}
\dfrac{1}{6}, & Y=0,\\
\dfrac{1}{2}, & Y=1.
\end{cases}
'''))
# Out:
# $\displaystyle
# \text{To find } a \text{ and } b,\text{ we use the defining property of conditional expectation.}
# $
# $\displaystyle
# \text{On the set } \{\omega_1,\omega_2\},
# $
# $\displaystyle
# \int_{\{\omega_1,\omega_2\}} E[X\mid Y]\,dP
# =
# \int_{\{\omega_1,\omega_2\}} X\,dP.
# $
# $\displaystyle
# \text{The left-hand side is}
# $
# $\displaystyle
# a\cdot P(\{\omega_1,\omega_2\})
# =
# a(0.50+0.10)
# =
# 0.60a.
# $
# $\displaystyle
# \text{The right-hand side is}
# $
# $\displaystyle
# 0\cdot 0.50 + 1\cdot 0.10 = 0.10.
# $
# $\displaystyle
# \text{So}
# $
# $\displaystyle
# 0.60a=0.10,
# $
# $\displaystyle
# \text{hence}
# $
# $\displaystyle
# a=\frac{0.10}{0.60}=\frac{1}{6}.
# $
# $\displaystyle
# \text{On the set } \{\omega_3,\omega_4\},
# $
# $\displaystyle
# \int_{\{\omega_3,\omega_4\}} E[X\mid Y]\,dP
# =
# \int_{\{\omega_3,\omega_4\}} X\,dP.
# $
# $\displaystyle
# \text{The left-hand side is}
# $
# $\displaystyle
# b\cdot P(\{\omega_3,\omega_4\})
# =
# b(0.20+0.20)
# ...

# %% [markdown]
# Q1.5

# %%
from IPython.display import display, Math

display(Math(r'''
\text{We now verify the defining property}
'''))

display(Math(r'''
\int_A E[X\mid Y]\,dP=\int_A X\,dP
\qquad \forall A\in\sigma(Y).
'''))

display(Math(r'''
\text{The sets in } \sigma(Y) \text{ are}
'''))

display(Math(r'''
\varnothing,\qquad \Omega,\qquad \{\omega_1,\omega_2\},\qquad \{\omega_3,\omega_4\}.
'''))

display(Math(r'''
\text{For } A=\varnothing,\text{ both integrals are clearly } 0.
'''))

display(Math(r'''
\text{For } A=\{\omega_1,\omega_2\},
'''))

display(Math(r'''
\int_A E[X\mid Y]\,dP = \frac{1}{6}\cdot 0.60 = 0.10,
'''))

display(Math(r'''
\int_A X\,dP = 0\cdot 0.50 + 1\cdot 0.10 = 0.10.
'''))

display(Math(r'''
\text{For } A=\{\omega_3,\omega_4\},
'''))

display(Math(r'''
\int_A E[X\mid Y]\,dP = \frac{1}{2}\cdot 0.40 = 0.20,
'''))

display(Math(r'''
\int_A X\,dP = 0\cdot 0.20 + 1\cdot 0.20 = 0.20.
'''))

display(Math(r'''
\text{For } A=\Omega,
'''))

display(Math(r'''
\int_\Omega E[X\mid Y]\,dP=\frac{1}{6}\cdot 0.60 + \frac{1}{2}\cdot 0.40=0.3.
'''))

display(Math(r'''
\int_\Omega X\,dP=0\cdot 0.50 + 1\cdot 0.10 + 0\cdot 0.20 + 1\cdot 0.20=0.30.
'''))

display(Math(r'''
\text{So the defining property holds for every } A\in\sigma(Y).
'''))

display(Math(r'''
\text{The last verification also demonstrates the Law of Total Expectation:}
'''))

display(Math(r'''
E[E[X|Y]] = E[X]
'''))
# Out:
# $\displaystyle
# \text{We now verify the defining property}
# $
# $\displaystyle
# \int_A E[X\mid Y]\,dP=\int_A X\,dP
# \qquad \forall A\in\sigma(Y).
# $
# $\displaystyle
# \text{The sets in } \sigma(Y) \text{ are}
# $
# $\displaystyle
# \varnothing,\qquad \Omega,\qquad \{\omega_1,\omega_2\},\qquad \{\omega_3,\omega_4\}.
# $
# $\displaystyle
# \text{For } A=\varnothing,\text{ both integrals are clearly } 0.
# $
# $\displaystyle
# \text{For } A=\{\omega_1,\omega_2\},
# $
# $\displaystyle
# \int_A E[X\mid Y]\,dP = \frac{1}{6}\cdot 0.60 = 0.10,
# $
# $\displaystyle
# \int_A X\,dP = 0\cdot 0.50 + 1\cdot 0.10 = 0.10.
# $
# $\displaystyle
# \text{For } A=\{\omega_3,\omega_4\},
# $
# $\displaystyle
# \int_A E[X\mid Y]\,dP = \frac{1}{2}\cdot 0.40 = 0.20,
# $
# $\displaystyle
# \int_A X\,dP = 0\cdot 0.20 + 1\cdot 0.20 = 0.20.
# $
# $\displaystyle
# \text{For } A=\Omega,
# $
# $\displaystyle
# \int_\Omega E[X\mid Y]\,dP=\frac{1}{6}\cdot 0.60 + \frac{1}{2}\cdot 0.40=0.3.
# $
# $\displaystyle
# ...

# %% [markdown]
# Q1.6

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Using the product rule }
p_{X|Y}(x \mid y) = \frac{P(X=x, Y=y)}{P(Y=y)},
\text{ we calculate:}
'''))

display(Math(r'''
\textbf{For } Y=0:
'''))

display(Math(r'''
p_{X|Y}(1 \mid 0)
= \frac{P(X=1, Y=0)}{P(Y=0)}
= \frac{P(\{\omega_2\})}{0.60}
= \frac{0.10}{0.60}
= \mathbf{\frac{1}{6}}
'''))

display(Math(r'''
\textbf{For } Y=1:
'''))

display(Math(r'''
p_{X|Y}(1 \mid 1)
= \frac{P(X=1, Y=1)}{P(Y=1)}
= \frac{P(\{\omega_4\})}{0.40}
= \frac{0.20}{0.40}
= \mathbf{\frac{1}{2}}
'''))

display(Math(r'''
\text{(The probabilities for } X=0 \text{ are complements: } 5/6 \text{ and } 1/2.)
'''))

display(Math(r'''
\text{So the conditional fraud probabilities are:}
'''))

display(Math(r'''
P(\text{fraud} \mid Y=0)=\frac{1}{6}\approx 0.167
'''))

display(Math(r'''
P(\text{fraud} \mid Y=1)=\frac{1}{2}=0.50
'''))

display(Math(r'''
\text{This is exactly the kind of quantity used in fraud risk scoring systems.}
'''))
# Out:
# $\displaystyle
# \text{Using the product rule }
# p_{X|Y}(x \mid y) = \frac{P(X=x, Y=y)}{P(Y=y)},
# \text{ we calculate:}
# $
# $\displaystyle
# \textbf{For } Y=0:
# $
# $\displaystyle
# p_{X|Y}(1 \mid 0)
# = \frac{P(X=1, Y=0)}{P(Y=0)}
# = \frac{P(\{\omega_2\})}{0.60}
# = \frac{0.10}{0.60}
# = \mathbf{\frac{1}{6}}
# $
# $\displaystyle
# \textbf{For } Y=1:
# $
# $\displaystyle
# p_{X|Y}(1 \mid 1)
# = \frac{P(X=1, Y=1)}{P(Y=1)}
# = \frac{P(\{\omega_4\})}{0.40}
# = \frac{0.20}{0.40}
# = \mathbf{\frac{1}{2}}
# $
# $\displaystyle
# \text{(The probabilities for } X=0 \text{ are complements: } 5/6 \text{ and } 1/2.)
# $
# $\displaystyle
# \text{So the conditional fraud probabilities are:}
# $
# $\displaystyle
# P(\text{fraud} \mid Y=0)=\frac{1}{6}\approx 0.167
# $
# $\displaystyle
# P(\text{fraud} \mid Y=1)=\frac{1}{2}=0.50
# $
# $\displaystyle
# \text{This is exactly the kind of quantity used in fraud risk scoring systems.}
# $

# %% [markdown]
# Q1.7

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Now we apply the discrete summary formula:}
'''))

display(Math(r'''
\mathbb{E}[X\mid Y=y] = \sum_{x \in \{0,1\}} x \cdot p_{X|Y}(x \mid y)
'''))

display(Math(r'''
\textbf{Evaluation at } y=0:
'''))

display(Math(r'''
\mathbb{E}[X\mid Y=0]
= (0 \cdot p_{X|Y}(0 \mid 0)) + (1 \cdot p_{X|Y}(1 \mid 0))
= 0 + (1 \cdot \tfrac{1}{6})
= \mathbf{\tfrac{1}{6}}
'''))

display(Math(r'''
\textbf{Evaluation at } y=1:
'''))

display(Math(r'''
\mathbb{E}[X\mid Y=1]
= (0 \cdot p_{X|Y}(0 \mid 1)) + (1 \cdot p_{X|Y}(1 \mid 1))
= 0 + (1 \cdot \tfrac{1}{2})
= \mathbf{\tfrac{1}{2}}
'''))
# Out:
# $\displaystyle
# \text{Now we apply the discrete summary formula:}
# $
# $\displaystyle
# \mathbb{E}[X\mid Y=y] = \sum_{x \in \{0,1\}} x \cdot p_{X|Y}(x \mid y)
# $
# $\displaystyle
# \textbf{Evaluation at } y=0:
# $
# $\displaystyle
# \mathbb{E}[X\mid Y=0]
# = (0 \cdot p_{X|Y}(0 \mid 0)) + (1 \cdot p_{X|Y}(1 \mid 0))
# = 0 + (1 \cdot \tfrac{1}{6})
# = \mathbf{\tfrac{1}{6}}
# $
# $\displaystyle
# \textbf{Evaluation at } y=1:
# $
# $\displaystyle
# \mathbb{E}[X\mid Y=1]
# = (0 \cdot p_{X|Y}(0 \mid 1)) + (1 \cdot p_{X|Y}(1 \mid 1))
# = 0 + (1 \cdot \tfrac{1}{2})
# = \mathbf{\tfrac{1}{2}}
# $

# %% [markdown]
# Q1.8

# %%
from IPython.display import display, Math

display(Math(r'''
\text{We compute the Minimum Mean Square Error (MMSE), which is:}
'''))

display(Math(r'''
\text{MSE}_{\min}
= \mathbb{E}[(X - \mathbb{E}[X \mid Y])^2]
= \mathbb{E}[\mathrm{Var}(X \mid Y)].
'''))

display(Math(r'''
\text{First, compute conditional variances. Since } X \mid Y=y \sim \text{Bernoulli}(p),
\mathrm{Var}(X \mid Y=y)=p(1-p).
'''))

display(Math(r'''
\textbf{For } Y=0:
\quad
\mathrm{Var}(X \mid Y=0)
= \frac{1}{6}\left(1-\frac{1}{6}\right)
= \frac{5}{36}.
'''))

display(Math(r'''
\textbf{For } Y=1:
\quad
\mathrm{Var}(X \mid Y=1)
= \frac{1}{2}\left(1-\frac{1}{2}\right)
= \frac{1}{4}.
'''))

display(Math(r'''
\text{Now take expectation over } Y:
'''))

display(Math(r'''
\mathbb{E}[\mathrm{Var}(X \mid Y)]
= \mathrm{Var}(X \mid Y=0)P(Y=0)
+ \mathrm{Var}(X \mid Y=1)P(Y=1).
'''))

display(Math(r'''
= \left(\frac{5}{36} \cdot 0.60\right)
+ \left(\frac{1}{4} \cdot 0.40\right)
'''))

display(Math(r'''
= \left(\frac{5}{36} \cdot \frac{3}{5}\right)
+ \left(\frac{1}{4} \cdot \frac{2}{5}\right)
'''))

display(Math(r'''
= \frac{1}{12} + \frac{1}{10}
= \frac{11}{60}
\approx 0.1833.
'''))

display(Math(r'''
\text{Thus, the MMSE is } \frac{11}{60} \approx 0.1833.
'''))

display(Math(r'''
\text{This is the lowest possible average squared error achievable using } Y.
'''))
# Out:
# $\displaystyle
# \text{We compute the Minimum Mean Square Error (MMSE), which is:}
# $
# $\displaystyle
# \text{MSE}_{\min}
# = \mathbb{E}[(X - \mathbb{E}[X \mid Y])^2]
# = \mathbb{E}[\mathrm{Var}(X \mid Y)].
# $
# $\displaystyle
# \text{First, compute conditional variances. Since } X \mid Y=y \sim \text{Bernoulli}(p),
# \mathrm{Var}(X \mid Y=y)=p(1-p).
# $
# $\displaystyle
# \textbf{For } Y=0:
# \quad
# \mathrm{Var}(X \mid Y=0)
# = \frac{1}{6}\left(1-\frac{1}{6}\right)
# = \frac{5}{36}.
# $
# $\displaystyle
# \textbf{For } Y=1:
# \quad
# \mathrm{Var}(X \mid Y=1)
# = \frac{1}{2}\left(1-\frac{1}{2}\right)
# = \frac{1}{4}.
# $
# $\displaystyle
# \text{Now take expectation over } Y:
# $
# $\displaystyle
# \mathbb{E}[\mathrm{Var}(X \mid Y)]
# = \mathrm{Var}(X \mid Y=0)P(Y=0)
# + \mathrm{Var}(X \mid Y=1)P(Y=1).
# $
# $\displaystyle
# = \left(\frac{5}{36} \cdot 0.60\right)
# + \left(\frac{1}{4} \cdot 0.40\right)
# $
# $\displaystyle
# = \left(\frac{5}{36} \cdot \frac{3}{5}\right)
# ...

# %% [markdown]
# Q1.9

# %%
from IPython.display import display, Math

display(Math(r'''
\text{If the bank ignores } Y \text{ and uses } \mathbb{E}[X]=0.30,
\text{ the error becomes the variance of } X.
'''))

display(Math(r'''
\text{Global MSE} = \mathbb{E}[(X-\mathbb{E}[X])^2] = \mathrm{Var}(X).
'''))

display(Math(r'''
\text{Since } X \sim \text{Bernoulli}(p=0.30),
\quad \mathrm{Var}(X)=p(1-p)=0.30(0.70)=\mathbf{0.21}.
'''))

display(Math(r'''
\textbf{Comparing the errors:}
'''))

display(Math(r'''
\text{Optimal MSE (with } Y\text{)} = \mathbb{E}[\mathrm{Var}(X\mid Y)] = \frac{11}{60} \approx 0.1833
'''))

display(Math(r'''
\text{Global MSE (without } Y\text{)} = \mathrm{Var}(X) = 0.21
'''))

display(Math(r'''
\text{Using } Y \text{ reduces error from } 0.21 \text{ to } 0.1833.
'''))

display(Math(r'''
\textbf{Law of Total Variance:}
'''))

display(Math(r'''
\mathrm{Var}(X)=\mathbb{E}[\mathrm{Var}(X\mid Y)] + \mathrm{Var}(\mathbb{E}[X\mid Y]).
'''))

display(Math(r'''
\textbf{Compute explained variance:}
'''))

display(Math(r'''
\mathbb{E}[X\mid Y]=
\begin{cases}
\frac{1}{6}, & P=0.6\\
\frac{1}{2}, & P=0.4
\end{cases}
'''))

display(Math(r'''
\mathrm{Var}(\mathbb{E}[X\mid Y])
=
\mathbb{E}[(\mathbb{E}[X\mid Y])^2] - (\mathbb{E}[X])^2
'''))

display(Math(r'''
= \left(\frac{1}{36}\cdot 0.6 + \frac{1}{4}\cdot 0.4\right) - (0.3)^2
'''))

display(Math(r'''
= (0.0166 + 0.1) - 0.09
= \mathbf{0.0267}.
'''))

display(Math(r'''
\textbf{Final decomposition:}
'''))

display(Math(r'''
0.21 = 0.1833 + 0.0267
'''))

display(Math(r'''
\text{(Total Error) = (Unexplained Error) + (Explained Error)}.
'''))

display(Math(r'''
\text{Interpretation: } Y \text{ provides predictive power equal to } 0.0267.
'''))
# Out:
# $\displaystyle
# \text{If the bank ignores } Y \text{ and uses } \mathbb{E}[X]=0.30,
# \text{ the error becomes the variance of } X.
# $
# $\displaystyle
# \text{Global MSE} = \mathbb{E}[(X-\mathbb{E}[X])^2] = \mathrm{Var}(X).
# $
# $\displaystyle
# \text{Since } X \sim \text{Bernoulli}(p=0.30),
# \quad \mathrm{Var}(X)=p(1-p)=0.30(0.70)=\mathbf{0.21}.
# $
# $\displaystyle
# \textbf{Comparing the errors:}
# $
# $\displaystyle
# \text{Optimal MSE (with } Y\text{)} = \mathbb{E}[\mathrm{Var}(X\mid Y)] = \frac{11}{60} \approx 0.1833
# $
# $\displaystyle
# \text{Global MSE (without } Y\text{)} = \mathrm{Var}(X) = 0.21
# $
# $\displaystyle
# \text{Using } Y \text{ reduces error from } 0.21 \text{ to } 0.1833.
# $
# $\displaystyle
# \textbf{Law of Total Variance:}
# $
# $\displaystyle
# \mathrm{Var}(X)=\mathbb{E}[\mathrm{Var}(X\mid Y)] + \mathrm{Var}(\mathbb{E}[X\mid Y]).
# $
# $\displaystyle
# \textbf{Compute explained variance:}
# $
# $\displaystyle
# \mathbb{E}[X\mid Y]=
# \begin{cases}
# ...

# %% [markdown]
# Q1.10

# %%
from IPython.display import display, Math

display(Math(r'''
\textbf{1. Joint Distribution } P(X,Y)
'''))

display(Math(r'''
P(X=0,Y=0)=0.50,\quad
P(X=1,Y=0)=0.10,\quad
P(X=0,Y=1)=0.20,\quad
P(X=1,Y=1)=0.20
'''))

display(Math(r'''
P(Y=0)=0.60,\quad P(Y=1)=0.40
'''))

display(Math(r'''
P(X=0)=0.70,\quad P(X=1)=0.30
'''))

display(Math(r'''
\textbf{2. Conditional Entropy } H(X\mid Y)
'''))

display(Math(r'''
P(X=1\mid Y=0)=\frac{1}{6},\quad P(X=0\mid Y=0)=\frac{5}{6}
'''))

display(Math(r'''
H(X\mid Y=0)\approx -\left[\frac{1}{6}\log_2\frac{1}{6}+\frac{5}{6}\log_2\frac{5}{6}\right]\approx 0.650
'''))

display(Math(r'''
P(X=1\mid Y=1)=\frac{1}{2},\quad P(X=0\mid Y=1)=\frac{1}{2}
'''))

display(Math(r'''
H(X\mid Y=1)=1.00
'''))

display(Math(r'''
H(X\mid Y)=0.60(0.650)+0.40(1.00)=0.790\ \text{bits}
'''))

display(Math(r'''
\textbf{3. Entropy of } X
'''))

display(Math(r'''
H(X)=-(0.70\log_2 0.70+0.30\log_2 0.30)\approx 0.881\ \text{bits}
'''))

display(Math(r'''
\textbf{4. Mutual Information}
'''))

display(Math(r'''
I(X;Y)=H(X)-H(X\mid Y)=0.881-0.790=0.091\ \text{bits}
'''))

display(Math(r'''
\textbf{5. Interpretation}
'''))

display(Math(r'''
H(X)=0.881 \quad \text{(total uncertainty)}
'''))

display(Math(r'''
H(X\mid Y)=0.790 \quad \text{(remaining uncertainty after knowing } Y)
'''))

display(Math(r'''
I(X;Y)=0.091 \quad \text{(information gained from } Y)
'''))

display(Math(r'''
\text{Knowing } Y \text{ reduces uncertainty in } X \text{ by about } 10.3\%.
'''))
# Out:
# $\displaystyle
# \textbf{1. Joint Distribution } P(X,Y)
# $
# $\displaystyle
# P(X=0,Y=0)=0.50,\quad
# P(X=1,Y=0)=0.10,\quad
# P(X=0,Y=1)=0.20,\quad
# P(X=1,Y=1)=0.20
# $
# $\displaystyle
# P(Y=0)=0.60,\quad P(Y=1)=0.40
# $
# $\displaystyle
# P(X=0)=0.70,\quad P(X=1)=0.30
# $
# $\displaystyle
# \textbf{2. Conditional Entropy } H(X\mid Y)
# $
# $\displaystyle
# P(X=1\mid Y=0)=\frac{1}{6},\quad P(X=0\mid Y=0)=\frac{5}{6}
# $
# $\displaystyle
# H(X\mid Y=0)\approx -\left[\frac{1}{6}\log_2\frac{1}{6}+\frac{5}{6}\log_2\frac{5}{6}\right]\approx 0.650
# $
# $\displaystyle
# P(X=1\mid Y=1)=\frac{1}{2},\quad P(X=0\mid Y=1)=\frac{1}{2}
# $
# $\displaystyle
# H(X\mid Y=1)=1.00
# $
# $\displaystyle
# H(X\mid Y)=0.60(0.650)+0.40(1.00)=0.790\ \text{bits}
# $
# $\displaystyle
# \textbf{3. Entropy of } X
# $
# $\displaystyle
# H(X)=-(0.70\log_2 0.70+0.30\log_2 0.30)\approx 0.881\ \text{bits}
# $
# $\displaystyle
# \textbf{4. Mutual Information}
# $
# $\displaystyle
# ...

# %% [markdown]
# Q02)

# %% [markdown]
# 1.DEFINITION

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Let } \mathbf{Z} =
\begin{bmatrix}
\mathbf{X} \\
\mathbf{Y}
\end{bmatrix}
\in \mathbb{R}^{n+m}.
'''))

display(Math(r'''
\text{A random variable } \mathbf{Z} \text{ has a joint multivariate normal distribution if every linear combination}
\text{ of its components is univariate normal.}
'''))

display(Math(r'''
\text{For } \mathbf{Z} \text{ to have a joint density function (i.e., be absolutely continuous), }
\boldsymbol{\Sigma} \text{ must be non-singular (positive definite).}
'''))

display(Math(r'''
f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z}) =
\frac{1}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}|}}
\exp\left(
-\frac{1}{2}(\mathbf{z}-\boldsymbol{\mu})^T
\boldsymbol{\Sigma}^{-1}
(\mathbf{z}-\boldsymbol{\mu})
\right).
'''))

display(Math(r'''
\boldsymbol{\mu} = \mathbb{E}[\mathbf{Z}] =
\begin{bmatrix}
\boldsymbol{\mu}_X \\
\boldsymbol{\mu}_Y
\end{bmatrix}
\in \mathbb{R}^{n+m}.
'''))

display(Math(r'''
\boldsymbol{\Sigma} =
\begin{bmatrix}
\boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\
\boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY}
\end{bmatrix}
'''))

display(Math(r'''
\boldsymbol{\Sigma}_{XX} = \mathrm{Var}(\mathbf{X}), \quad
\boldsymbol{\Sigma}_{YY} = \mathrm{Var}(\mathbf{Y}), \quad
\boldsymbol{\Sigma}_{XY} = \mathrm{Cov}(\mathbf{X}, \mathbf{Y}) = \boldsymbol{\Sigma}_{YX}^T.
'''))

display(Math(r'''
|\boldsymbol{\Sigma}| \text{ is the determinant of the covariance matrix and ensures normalization of the density.}
'''))
# Out:
# $\displaystyle
# \text{Let } \mathbf{Z} =
# \begin{bmatrix}
# \mathbf{X} \\
# \mathbf{Y}
# \end{bmatrix}
# \in \mathbb{R}^{n+m}.
# $
# $\displaystyle
# \text{A random variable } \mathbf{Z} \text{ has a joint multivariate normal distribution if every linear combination}
# \text{ of its components is univariate normal.}
# $
# $\displaystyle
# \text{For } \mathbf{Z} \text{ to have a joint density function (i.e., be absolutely continuous), }
# \boldsymbol{\Sigma} \text{ must be non-singular (positive definite).}
# $
# $\displaystyle
# f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z}) =
# \frac{1}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}|}}
# \exp\left(
# -\frac{1}{2}(\mathbf{z}-\boldsymbol{\mu})^T
# \boldsymbol{\Sigma}^{-1}
# (\mathbf{z}-\boldsymbol{\mu})
# \right).
# $
# $\displaystyle
# \boldsymbol{\mu} = \mathbb{E}[\mathbf{Z}] =
# \begin{bmatrix}
# \boldsymbol{\mu}_X \\
# \boldsymbol{\mu}_Y
# \end{bmatrix}
# \in \mathbb{R}^{n+m}.
# $
# $\displaystyle
# \boldsymbol{\Sigma} =
# \begin{bmatrix}
# ...

# %% [markdown]
# 2.MARGINAL DISTRIBUTIONS

# %%
from IPython.display import display, Math

display(Math(r'''
\text{To derive the marginal density of } \mathbf{X} \text{ from } (\mathbf{X}, \mathbf{Y}),
\text{ we integrate over } \mathbf{Y}.
'''))

display(Math(r'''
f_{\mathbf{X}}(\mathbf{x}) = \int f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})\, d\mathbf{y}.
'''))

display(Math(r'''
\text{The difficulty comes from the quadratic form in the exponential, which we handle using}
\text{ block matrix inversion (Schur complement) and completing the square.}
'''))

display(Math(r'''
Q =
\begin{bmatrix}
\mathbf{x}-\boldsymbol{\mu}_x \\
\mathbf{y}-\boldsymbol{\mu}_y
\end{bmatrix}^T
\boldsymbol{\Sigma}^{-1}
\begin{bmatrix}
\mathbf{x}-\boldsymbol{\mu}_x \\
\mathbf{y}-\boldsymbol{\mu}_y
\end{bmatrix}.
'''))

display(Math(r'''
\boldsymbol{\Sigma} =
\begin{bmatrix}
\boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\
\boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY}
\end{bmatrix}.
'''))

display(Math(r'''
\text{Using the Schur complement of } \boldsymbol{\Sigma}_{XX},
\text{ the inverse can be factorized as:}
'''))

display(Math(r'''
\boldsymbol{\Sigma}^{-1} =
\begin{bmatrix}
\mathbf{I} & -\boldsymbol{\Sigma}_{XX}^{-1}\boldsymbol{\Sigma}_{XY} \\
\mathbf{0} & \mathbf{I}
\end{bmatrix}^T
\begin{bmatrix}
\boldsymbol{\Sigma}_{XX}^{-1} & \mathbf{0} \\
\mathbf{0} & \mathbf{S}_{YY}^{-1}
\end{bmatrix}
\begin{bmatrix}
\mathbf{I} & -\boldsymbol{\Sigma}_{XX}^{-1}\boldsymbol{\Sigma}_{XY} \\
\mathbf{0} & \mathbf{I}
\end{bmatrix}.
'''))

display(Math(r'''
\text{where } \mathbf{S}_{YY}
= \boldsymbol{\Sigma}_{YY}
- \boldsymbol{\Sigma}_{YX}\boldsymbol{\Sigma}_{XX}^{-1}\boldsymbol{\Sigma}_{XY}.
'''))
# Out:
# $\displaystyle
# \text{To derive the marginal density of } \mathbf{X} \text{ from } (\mathbf{X}, \mathbf{Y}),
# \text{ we integrate over } \mathbf{Y}.
# $
# $\displaystyle
# f_{\mathbf{X}}(\mathbf{x}) = \int f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})\, d\mathbf{y}.
# $
# $\displaystyle
# \text{The difficulty comes from the quadratic form in the exponential, which we handle using}
# \text{ block matrix inversion (Schur complement) and completing the square.}
# $
# $\displaystyle
# Q =
# \begin{bmatrix}
# \mathbf{x}-\boldsymbol{\mu}_x \\
# \mathbf{y}-\boldsymbol{\mu}_y
# \end{bmatrix}^T
# \boldsymbol{\Sigma}^{-1}
# \begin{bmatrix}
# \mathbf{x}-\boldsymbol{\mu}_x \\
# \mathbf{y}-\boldsymbol{\mu}_y
# \end{bmatrix}.
# $
# $\displaystyle
# \boldsymbol{\Sigma} =
# \begin{bmatrix}
# \boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\
# \boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY}
# \end{bmatrix}.
# $
# $\displaystyle
# ...

# %% [markdown]
# 2.1 MARGINAL DENSITY OF X

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Let } \widetilde{\mathbf{x}}=\mathbf{x}-\boldsymbol{\mu}_x,\quad
\widetilde{\mathbf{y}}=\mathbf{y}-\boldsymbol{\mu}_y.
'''))

display(Math(r'''
Q =
\widetilde{\mathbf{x}}^T \boldsymbol{\Sigma}_{XX}^{-1} \widetilde{\mathbf{x}}
+
(\widetilde{\mathbf{y}}-\mathbf{A}\widetilde{\mathbf{x}})^T
\mathbf{S}_{YY}^{-1}
(\widetilde{\mathbf{y}}-\mathbf{A}\widetilde{\mathbf{x}})
'''))

display(Math(r'''
\mathbf{A}=\boldsymbol{\Sigma}_{YX}\boldsymbol{\Sigma}_{XX}^{-1}.
'''))

display(Math(r'''
f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})
= C \cdot
\exp\left(-\frac{1}{2}\widetilde{\mathbf{x}}^T\boldsymbol{\Sigma}_{XX}^{-1}\widetilde{\mathbf{x}}\right)
\cdot
\exp\left(-\frac{1}{2}(\widetilde{\mathbf{y}}-\mathbf{m})^T\mathbf{S}_{YY}^{-1}(\widetilde{\mathbf{y}}-\mathbf{m})\right)
'''))

display(Math(r'''
\mathbf{m}=\mathbf{A}\widetilde{\mathbf{x}}.
'''))

display(Math(r'''
f_{\mathbf{X}}(\mathbf{x})
=\int_{\mathbb{R}^m} f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})\,d\mathbf{y}.
'''))

display(Math(r'''
f_{\mathbf{X}}(\mathbf{x})
= C \cdot e^{-\frac{1}{2}\widetilde{\mathbf{x}}^T\boldsymbol{\Sigma}_{XX}^{-1}\widetilde{\mathbf{x}}}
\int_{\mathbb{R}^m}
\exp\left(-\frac{1}{2}(\widetilde{\mathbf{y}}-\mathbf{m})^T\mathbf{S}_{YY}^{-1}(\widetilde{\mathbf{y}}-\mathbf{m})\right)
d\mathbf{y}
'''))

display(Math(r'''
\int_{\mathbb{R}^m}(\cdots)d\mathbf{y}
=
\sqrt{(2\pi)^m|\mathbf{S}_{YY}|}.
'''))

display(Math(r'''
|\boldsymbol{\Sigma}|
=
|\boldsymbol{\Sigma}_{XX}|\,|\mathbf{S}_{YY}|.
'''))

display(Math(r'''
f_{\mathbf{X}}(\mathbf{x})
=
\frac{1}{\sqrt{(2\pi)^n|\boldsymbol{\Sigma}_{XX}|}}
\exp\left(
-\frac{1}{2}(\mathbf{x}-\boldsymbol{\mu}_x)^T
\boldsymbol{\Sigma}_{XX}^{-1}
(\mathbf{x}-\boldsymbol{\mu}_x)
\right).
'''))

display(Math(r'''
\text{Thus, } \mathbf{X} \sim \mathcal{N}(\boldsymbol{\mu}_x,\boldsymbol{\Sigma}_{XX}).
'''))
# Out:
# $\displaystyle
# \text{Let } \widetilde{\mathbf{x}}=\mathbf{x}-\boldsymbol{\mu}_x,\quad
# \widetilde{\mathbf{y}}=\mathbf{y}-\boldsymbol{\mu}_y.
# $
# $\displaystyle
# Q =
# \widetilde{\mathbf{x}}^T \boldsymbol{\Sigma}_{XX}^{-1} \widetilde{\mathbf{x}}
# +
# (\widetilde{\mathbf{y}}-\mathbf{A}\widetilde{\mathbf{x}})^T
# \mathbf{S}_{YY}^{-1}
# (\widetilde{\mathbf{y}}-\mathbf{A}\widetilde{\mathbf{x}})
# $
# $\displaystyle
# \mathbf{A}=\boldsymbol{\Sigma}_{YX}\boldsymbol{\Sigma}_{XX}^{-1}.
# $
# $\displaystyle
# f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})
# = C \cdot
# \exp\left(-\frac{1}{2}\widetilde{\mathbf{x}}^T\boldsymbol{\Sigma}_{XX}^{-1}\widetilde{\mathbf{x}}\right)
# \cdot
# \exp\left(-\frac{1}{2}(\widetilde{\mathbf{y}}-\mathbf{m})^T\mathbf{S}_{YY}^{-1}(\widetilde{\mathbf{y}}-\mathbf{m})\right)
# $
# $\displaystyle
# \mathbf{m}=\mathbf{A}\widetilde{\mathbf{x}}.
# $
# $\displaystyle
# f_{\mathbf{X}}(\mathbf{x})
# ...

# %% [markdown]
# 2.2 MARGINAL DENSITY OF Y

# %%
from IPython.display import display, Math

display(Math(r'''
\text{The derivation for } f_{\mathbf{Y}}(\mathbf{y}) \text{ is symmetric to that of } \mathbf{X}.
'''))

display(Math(r'''
\text{We integrate out } \mathbf{x} \text{ to obtain the marginal of } \mathbf{Y}.
'''))

display(Math(r'''
Q =
\widetilde{\mathbf{y}}^T \boldsymbol{\Sigma}_{YY}^{-1} \widetilde{\mathbf{y}}
+
(\widetilde{\mathbf{x}}-\mathbf{B}\widetilde{\mathbf{y}})^T
\mathbf{S}_{XX}^{-1}
(\widetilde{\mathbf{x}}-\mathbf{B}\widetilde{\mathbf{y}})
'''))

display(Math(r'''
\widetilde{\mathbf{y}}=\mathbf{y}-\boldsymbol{\mu}_y
'''))

display(Math(r'''
\mathbf{B}=\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}
'''))

display(Math(r'''
\mathbf{S}_{XX}=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
'''))

display(Math(r'''
f_{\mathbf{Y}}(\mathbf{y})
=
\int_{\mathbb{R}^n}
f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})\,d\mathbf{x}
'''))

display(Math(r'''
f_{\mathbf{Y}}(\mathbf{y})
=
C \cdot
e^{-\frac{1}{2}\widetilde{\mathbf{y}}^T\boldsymbol{\Sigma}_{YY}^{-1}\widetilde{\mathbf{y}}}
\int_{\mathbb{R}^n}
\exp\left(
-\frac{1}{2}
(\widetilde{\mathbf{x}}-\mathbf{B}\widetilde{\mathbf{y}})^T
\mathbf{S}_{XX}^{-1}
(\widetilde{\mathbf{x}}-\mathbf{B}\widetilde{\mathbf{y}})
\right)
d\mathbf{x}
'''))

display(Math(r'''
\int_{\mathbb{R}^n}(\cdots)d\mathbf{x}
=
\sqrt{(2\pi)^n|\mathbf{S}_{XX}|}.
'''))

display(Math(r'''
|\boldsymbol{\Sigma}|
=
|\boldsymbol{\Sigma}_{YY}|\;|\mathbf{S}_{XX}|.
'''))

display(Math(r'''
f_{\mathbf{Y}}(\mathbf{y})
=
\frac{1}{\sqrt{(2\pi)^m|\boldsymbol{\Sigma}_{YY}|}}
\exp\left(
-\frac{1}{2}
(\mathbf{y}-\boldsymbol{\mu}_y)^T
\boldsymbol{\Sigma}_{YY}^{-1}
(\mathbf{y}-\boldsymbol{\mu}_y)
\right).
'''))

display(Math(r'''
\text{Thus, } \mathbf{Y} \sim \mathcal{N}(\boldsymbol{\mu}_y,\boldsymbol{\Sigma}_{YY}).
'''))
# Out:
# $\displaystyle
# \text{The derivation for } f_{\mathbf{Y}}(\mathbf{y}) \text{ is symmetric to that of } \mathbf{X}.
# $
# $\displaystyle
# \text{We integrate out } \mathbf{x} \text{ to obtain the marginal of } \mathbf{Y}.
# $
# $\displaystyle
# Q =
# \widetilde{\mathbf{y}}^T \boldsymbol{\Sigma}_{YY}^{-1} \widetilde{\mathbf{y}}
# +
# (\widetilde{\mathbf{x}}-\mathbf{B}\widetilde{\mathbf{y}})^T
# \mathbf{S}_{XX}^{-1}
# (\widetilde{\mathbf{x}}-\mathbf{B}\widetilde{\mathbf{y}})
# $
# $\displaystyle
# \widetilde{\mathbf{y}}=\mathbf{y}-\boldsymbol{\mu}_y
# $
# $\displaystyle
# \mathbf{B}=\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}
# $
# $\displaystyle
# \mathbf{S}_{XX}=
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
# $
# $\displaystyle
# f_{\mathbf{Y}}(\mathbf{y})
# =
# \int_{\mathbb{R}^n}
# f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})\,d\mathbf{x}
# $
# $\displaystyle
# f_{\mathbf{Y}}(\mathbf{y})
# =
# C \cdot
# ...

# %% [markdown]
# 3. CONDITIONAL DENSITY

# %%
from IPython.display import display, Math

display(Math(r'''
\text{To derive } f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x}\mid \mathbf{y}), \text{ we use:}
'''))

display(Math(r'''
f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x}\mid \mathbf{y})
=
\frac{f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})}{f_{\mathbf{Y}}(\mathbf{y})}.
'''))

display(Math(r'''
\text{From the Schur complement decomposition, the joint quadratic form is:}
'''))

display(Math(r'''
Q_{joint}
=
(\mathbf{y}-\boldsymbol{\mu}_y)^T \boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y)
+
(\mathbf{x}-\boldsymbol{\mu}^*)^T \mathbf{S}_{XX}^{-1}(\mathbf{x}-\boldsymbol{\mu}^*)
'''))

display(Math(r'''
\boldsymbol{\mu}^*
=
\boldsymbol{\mu}_x
+
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}
(\mathbf{y}-\boldsymbol{\mu}_y)
'''))

display(Math(r'''
\mathbf{S}_{XX}
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
'''))

display(Math(r'''
Q_{conditional}
=
Q_{joint}-Q_{marginal}
=
(\mathbf{x}-\boldsymbol{\mu}^*)^T \mathbf{S}_{XX}^{-1}(\mathbf{x}-\boldsymbol{\mu}^*).
'''))

display(Math(r'''
\textbf{Normalization constants:}
'''))

display(Math(r'''
\frac{1}{\sqrt{(2\pi)^{n+m}|\boldsymbol{\Sigma}|}}
\cdot
\sqrt{(2\pi)^m|\boldsymbol{\Sigma}_{YY}|}
=
\frac{1}{\sqrt{(2\pi)^n |\mathbf{S}_{XX}|}}.
'''))

display(Math(r'''
|\boldsymbol{\Sigma}|=|\boldsymbol{\Sigma}_{YY}|\;|\mathbf{S}_{XX}|.
'''))

display(Math(r'''
f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x}\mid \mathbf{y})
=
\frac{1}{\sqrt{(2\pi)^n|\mathbf{S}_{XX}|}}
\exp\left(
-\frac{1}{2}
(\mathbf{x}-\boldsymbol{\mu}^*)^T
\mathbf{S}_{XX}^{-1}
(\mathbf{x}-\boldsymbol{\mu}^*)
\right).
'''))

display(Math(r'''
(\mathbf{X}\mid \mathbf{Y}=\mathbf{y})
\sim \mathcal{N}(\boldsymbol{\mu}_{X|Y}, \boldsymbol{\Sigma}_{X|Y}).
'''))

display(Math(r'''
\boldsymbol{\mu}_{X|Y}
=
\boldsymbol{\mu}_x
+
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}
(\mathbf{y}-\boldsymbol{\mu}_y)
'''))

display(Math(r'''
\boldsymbol{\Sigma}_{X|Y}
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}
\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\textbf{Key insight: } \boldsymbol{\Sigma}_{X|Y} \text{ does not depend on } \mathbf{y}.
'''))

display(Math(r'''
\text{This connects directly to linear regression and Kalman filtering: the uncertainty is fixed,
but the mean updates with new information.}
'''))
# Out:
# $\displaystyle
# \text{To derive } f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x}\mid \mathbf{y}), \text{ we use:}
# $
# $\displaystyle
# f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x}\mid \mathbf{y})
# =
# \frac{f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})}{f_{\mathbf{Y}}(\mathbf{y})}.
# $
# $\displaystyle
# \text{From the Schur complement decomposition, the joint quadratic form is:}
# $
# $\displaystyle
# Q_{joint}
# =
# (\mathbf{y}-\boldsymbol{\mu}_y)^T \boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y)
# +
# (\mathbf{x}-\boldsymbol{\mu}^*)^T \mathbf{S}_{XX}^{-1}(\mathbf{x}-\boldsymbol{\mu}^*)
# $
# $\displaystyle
# \boldsymbol{\mu}^*
# =
# \boldsymbol{\mu}_x
# +
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}
# (\mathbf{y}-\boldsymbol{\mu}_y)
# $
# $\displaystyle
# \mathbf{S}_{XX}
# =
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
# $
# $\displaystyle
# Q_{conditional}
# =
# Q_{joint}-Q_{marginal}
# =
# ...

# %% [markdown]
# 4. CONDITIONAL EXPECTATION

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Let } g(y)=\mathbb{E}[X\mid Y=y].
\text{ By the Disintegration Theorem:}
'''))

display(Math(r'''
g(y)=\int_{\mathbb{R}^n} \mathbf{x}\, f_{\mathbf{X}\mid \mathbf{Y}}(\mathbf{x}\mid \mathbf{y})\, d\mathbf{x}.
'''))

display(Math(r'''
(\mathbf{X}\mid \mathbf{Y}=\mathbf{y})
\sim \mathcal{N}\Big(
\boldsymbol{\mu}_x
+
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y),
\;
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
\Big).
'''))

display(Math(r'''
\text{Thus, } g(y) \text{ is simply the mean of this Gaussian:}
'''))

display(Math(r'''
g(y)
=
\boldsymbol{\mu}_x
+
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y).
'''))

display(Math(r'''
\text{Therefore:}
'''))

display(Math(r'''
\mathbb{E}[X\mid Y=y]
=
\boldsymbol{\mu}_x
+
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y).
'''))

display(Math(r'''
\mathbb{E}[X\mid Y]
=
\boldsymbol{\mu}_x
+
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{Y}-\boldsymbol{\mu}_y).
'''))

display(Math(r'''
\text{Key insight: conditional expectation in the Gaussian case is an affine (linear + shift) function of } Y.
'''))
# Out:
# $\displaystyle
# \text{Let } g(y)=\mathbb{E}[X\mid Y=y].
# \text{ By the Disintegration Theorem:}
# $
# $\displaystyle
# g(y)=\int_{\mathbb{R}^n} \mathbf{x}\, f_{\mathbf{X}\mid \mathbf{Y}}(\mathbf{x}\mid \mathbf{y})\, d\mathbf{x}.
# $
# $\displaystyle
# (\mathbf{X}\mid \mathbf{Y}=\mathbf{y})
# \sim \mathcal{N}\Big(
# \boldsymbol{\mu}_x
# +
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y),
# \;
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
# \Big).
# $
# $\displaystyle
# \text{Thus, } g(y) \text{ is simply the mean of this Gaussian:}
# $
# $\displaystyle
# g(y)
# =
# \boldsymbol{\mu}_x
# +
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y).
# $
# $\displaystyle
# \text{Therefore:}
# $
# $\displaystyle
# \mathbb{E}[X\mid Y=y]
# =
# \boldsymbol{\mu}_x
# +
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y).
# $
# ...

# %% [markdown]
# 5. THE CONDITIONAL VARIANCES

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Since } (\mathbf{X} \mid \mathbf{Y}=\mathbf{y}) \sim \mathcal{N}\left(
\boldsymbol{\mu}_x + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y),
\;
\boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
\right),
'''))

display(Math(r'''
\mathrm{Var}(\mathbf{X}\mid \mathbf{Y}=\mathbf{y})
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\text{Since this does not depend on } \mathbf{y},
\quad
\mathrm{Var}(\mathbf{X}\mid \mathbf{Y})
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\mathbb{E}[\mathrm{Var}(\mathbf{X}\mid \mathbf{Y})]
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\mathbb{E}\!\left[(\mathbf{X}-\mathbb{E}[\mathbf{X}\mid \mathbf{Y}])^2\right]
=
\mathbb{E}[\mathrm{Var}(\mathbf{X}\mid \mathbf{Y})]
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\textbf{Law of Total Variance:}
\quad
\mathrm{Var}(\mathbf{X})
=
\mathbb{E}[\mathrm{Var}(\mathbf{X}\mid \mathbf{Y})]
+
\mathrm{Var}(\mathbb{E}[\mathbf{X}\mid \mathbf{Y}]).
'''))

display(Math(r'''
\mathrm{Var}(\mathbb{E}[\mathbf{X}\mid \mathbf{Y}])
=
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\textbf{Interpretation:}
'''))

display(Math(r'''
\text{Explained variance}
=
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\text{Unexplained variance}
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\text{So total variance splits into: signal (explained) + noise (residual).}
'''))
# Out:
# $\displaystyle
# \text{Since } (\mathbf{X} \mid \mathbf{Y}=\mathbf{y}) \sim \mathcal{N}\left(
# \boldsymbol{\mu}_x + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y),
# \;
# \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
# \right),
# $
# $\displaystyle
# \mathrm{Var}(\mathbf{X}\mid \mathbf{Y}=\mathbf{y})
# =
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
# $
# $\displaystyle
# \text{Since this does not depend on } \mathbf{y},
# \quad
# \mathrm{Var}(\mathbf{X}\mid \mathbf{Y})
# =
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
# $
# $\displaystyle
# \mathbb{E}[\mathrm{Var}(\mathbf{X}\mid \mathbf{Y})]
# =
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
# $
# $\displaystyle
# ...

# %% [markdown]
# 6. THE ENTROPT OF THE CONDITIONAL EXPECTATION AND MUTUAL INFORMATION

# %% [markdown]
# 6.1.THE DIFFERENTIAL ENTROPY OF A MULTIVARIATE GAUSSIAN

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Consider } \mathbf{Z}=
\begin{bmatrix}
\mathbf{X}\\
\mathbf{Y}
\end{bmatrix}
\in \mathbb{R}^{n+m},\quad
\mathbf{Z}\sim \mathcal{N}(\boldsymbol{\mu},\boldsymbol{\Sigma}).
'''))

display(Math(r'''
f_{\mathbf{X},\mathbf{Y}}(\mathbf{z})
=
\frac{1}{\sqrt{(2\pi)^{n+m}|\boldsymbol{\Sigma}|}}
\exp\left(
-\frac{1}{2}
(\mathbf{z}-\boldsymbol{\mu})^T
\boldsymbol{\Sigma}^{-1}
(\mathbf{z}-\boldsymbol{\mu})
\right).
'''))

display(Math(r'''
h(\mathbf{Z})
=
-\mathbb{E}[\ln f_{\mathbf{X},\mathbf{Y}}(\mathbf{z})].
'''))

display(Math(r'''
\textbf{Step A: Log-density}
'''))

display(Math(r'''
\ln f_{\mathbf{X},\mathbf{Y}}(\mathbf{z})
=
-\frac{1}{2}\ln\left((2\pi)^{n+m}|\boldsymbol{\Sigma}|\right)
-\frac{1}{2}
(\mathbf{z}-\boldsymbol{\mu})^T
\boldsymbol{\Sigma}^{-1}
(\mathbf{z}-\boldsymbol{\mu}).
'''))

display(Math(r'''
\textbf{Step B: Expectation}
'''))

display(Math(r'''
h(\mathbf{Z})
=
\frac{1}{2}\ln\left((2\pi)^{n+m}|\boldsymbol{\Sigma}|\right)
+
\frac{1}{2}\mathbb{E}\!\left[
(\mathbf{Z}-\boldsymbol{\mu})^T
\boldsymbol{\Sigma}^{-1}
(\mathbf{Z}-\boldsymbol{\mu})
\right].
'''))

display(Math(r'''
\textbf{Step C: Quadratic form identity}
'''))

display(Math(r'''
\mathbb{E}\!\left[
(\mathbf{Z}-\boldsymbol{\mu})^T
\boldsymbol{\Sigma}^{-1}
(\mathbf{Z}-\boldsymbol{\mu})
\right]
=
\mathrm{Tr}(\boldsymbol{\Sigma}^{-1}\boldsymbol{\Sigma})
=
n+m.
'''))

display(Math(r'''
\textbf{Step D: Final result}
'''))

display(Math(r'''
h(\mathbf{Z})
=
\frac{1}{2}\ln\left((2\pi)^{n+m}|\boldsymbol{\Sigma}|\right)
+
\frac{n+m}{2}.
'''))

display(Math(r'''
h(\mathbf{Z})
=
\frac{1}{2}\ln\left((2\pi e)^{n+m}|\boldsymbol{\Sigma}|\right).
'''))

display(Math(r'''
\text{Thus, the differential entropy of a multivariate Gaussian depends only on its covariance determinant.}
'''))
# Out:
# $\displaystyle
# \text{Consider } \mathbf{Z}=
# \begin{bmatrix}
# \mathbf{X}\\
# \mathbf{Y}
# \end{bmatrix}
# \in \mathbb{R}^{n+m},\quad
# \mathbf{Z}\sim \mathcal{N}(\boldsymbol{\mu},\boldsymbol{\Sigma}).
# $
# $\displaystyle
# f_{\mathbf{X},\mathbf{Y}}(\mathbf{z})
# =
# \frac{1}{\sqrt{(2\pi)^{n+m}|\boldsymbol{\Sigma}|}}
# \exp\left(
# -\frac{1}{2}
# (\mathbf{z}-\boldsymbol{\mu})^T
# \boldsymbol{\Sigma}^{-1}
# (\mathbf{z}-\boldsymbol{\mu})
# \right).
# $
# $\displaystyle
# h(\mathbf{Z})
# =
# -\mathbb{E}[\ln f_{\mathbf{X},\mathbf{Y}}(\mathbf{z})].
# $
# $\displaystyle
# \textbf{Step A: Log-density}
# $
# $\displaystyle
# \ln f_{\mathbf{X},\mathbf{Y}}(\mathbf{z})
# =
# -\frac{1}{2}\ln\left((2\pi)^{n+m}|\boldsymbol{\Sigma}|\right)
# -\frac{1}{2}
# (\mathbf{z}-\boldsymbol{\mu})^T
# \boldsymbol{\Sigma}^{-1}
# (\mathbf{z}-\boldsymbol{\mu}).
# $
# $\displaystyle
# \textbf{Step B: Expectation}
# $
# $\displaystyle
# h(\mathbf{Z})
# =
# ...

# %% [markdown]
# 6.2 CONDITIONAL ENTROPY

# %%
from IPython.display import display, Math

display(Math(r'''
\text{The conditional entropy } h(\mathbf{X}\mid \mathbf{Y})
\text{ measures the remaining uncertainty in } \mathbf{X} \text{ after observing } \mathbf{Y}.
'''))

display(Math(r'''
(\mathbf{X}\mid \mathbf{Y}=\mathbf{y})
\sim \mathcal{N}\left(
\boldsymbol{\mu}_x
+
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y),
\;
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
\right).
'''))

display(Math(r'''
\boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\text{Key point: } \boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}} \text{ does not depend on } \mathbf{y}.
'''))

display(Math(r'''
h(\mathbf{X}\mid \mathbf{Y})
=
\frac{1}{2}
\ln\left((2\pi e)^n
\left|
\boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}
\right|
\right).
'''))

display(Math(r'''
=
\frac{1}{2}
\ln\left((2\pi e)^n
\left|
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
\right|
\right).
'''))

display(Math(r'''
\textbf{Interpretation:}
\text{ conditioning reduces entropy by replacing } \boldsymbol{\Sigma}_{XX}
\text{ with the Schur complement.}
'''))
# Out:
# $\displaystyle
# \text{The conditional entropy } h(\mathbf{X}\mid \mathbf{Y})
# \text{ measures the remaining uncertainty in } \mathbf{X} \text{ after observing } \mathbf{Y}.
# $
# $\displaystyle
# (\mathbf{X}\mid \mathbf{Y}=\mathbf{y})
# \sim \mathcal{N}\left(
# \boldsymbol{\mu}_x
# +
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_y),
# \;
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
# \right).
# $
# $\displaystyle
# \boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}
# =
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
# $
# $\displaystyle
# \text{Key point: } \boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}} \text{ does not depend on } \mathbf{y}.
# $
# $\displaystyle
# h(\mathbf{X}\mid \mathbf{Y})
# =
# \frac{1}{2}
# \ln\left((2\pi e)^n
# \left|
# \boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}
# \right|
# \right).
# $
# ...

# %% [markdown]
# 6.3 THE ENTROPY OF THE CONDITIONAL EXPECTATION

# %%
from IPython.display import display, Math

display(Math(r'''
\text{From the law of total variance, the explained variance is}
'''))

display(Math(r'''
\mathrm{Var}(\mathbb{E}[\mathbf{X}\mid \mathbf{Y}])
=
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\text{Thus, the differential entropy of } \mathbb{E}[\mathbf{X}\mid \mathbf{Y}] \text{ is}
'''))

display(Math(r'''
h(\mathbb{E}[\mathbf{X}\mid \mathbf{Y}])
=
\frac{1}{2}
\ln\left((2\pi e)^n
\left|
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
\right|
\right).
'''))

display(Math(r'''
\textbf{Interpretation:}
\text{this entropy measures the uncertainty in the predicted mean of } \mathbf{X}
\text{ induced by randomness in } \mathbf{Y}.
'''))
# Out:
# $\displaystyle
# \text{From the law of total variance, the explained variance is}
# $
# $\displaystyle
# \mathrm{Var}(\mathbb{E}[\mathbf{X}\mid \mathbf{Y}])
# =
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
# $
# $\displaystyle
# \text{Thus, the differential entropy of } \mathbb{E}[\mathbf{X}\mid \mathbf{Y}] \text{ is}
# $
# $\displaystyle
# h(\mathbb{E}[\mathbf{X}\mid \mathbf{Y}])
# =
# \frac{1}{2}
# \ln\left((2\pi e)^n
# \left|
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
# \right|
# \right).
# $
# $\displaystyle
# \textbf{Interpretation:}
# \text{this entropy measures the uncertainty in the predicted mean of } \mathbf{X}
# \text{ induced by randomness in } \mathbf{Y}.
# $

# %% [markdown]
# 6.4. MUTUAL INFORMATION

# %%
from IPython.display import display, Math

display(Math(r'''
\text{Mutual information is defined as}
'''))

display(Math(r'''
I(\mathbf{X};\mathbf{Y}) = h(\mathbf{X}) - h(\mathbf{X}\mid \mathbf{Y}).
'''))

display(Math(r'''
\text{Substituting Gaussian entropy expressions:}
'''))

display(Math(r'''
I(\mathbf{X};\mathbf{Y})
=
\frac{1}{2}\ln\left((2\pi e)^n|\boldsymbol{\Sigma}_{XX}|\right)
-
\frac{1}{2}\ln\left((2\pi e)^n|\boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}|\right).
'''))

display(Math(r'''
\text{Using } \ln A - \ln B = \ln\left(\frac{A}{B}\right),
\text{ the constants cancel:}
'''))

display(Math(r'''
I(\mathbf{X};\mathbf{Y})
=
\frac{1}{2}\ln\left(
\frac{|\boldsymbol{\Sigma}_{XX}|}{|\boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}|}
\right).
'''))

display(Math(r'''
\boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}
=
\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
'''))

display(Math(r'''
\text{Final form:}
'''))

display(Math(r'''
I(\mathbf{X};\mathbf{Y})
=
\frac{1}{2}\ln\left(
\frac{|\boldsymbol{\Sigma}_{XX}|}
{|\boldsymbol{\Sigma}_{XX}
-
\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}|}
\right).
'''))

display(Math(r'''
\textbf{Interpretation:}
\text{mutual information measures how much uncertainty in } \mathbf{X}
\text{ is removed by observing } \mathbf{Y}.
'''))
# Out:
# $\displaystyle
# \text{Mutual information is defined as}
# $
# $\displaystyle
# I(\mathbf{X};\mathbf{Y}) = h(\mathbf{X}) - h(\mathbf{X}\mid \mathbf{Y}).
# $
# $\displaystyle
# \text{Substituting Gaussian entropy expressions:}
# $
# $\displaystyle
# I(\mathbf{X};\mathbf{Y})
# =
# \frac{1}{2}\ln\left((2\pi e)^n|\boldsymbol{\Sigma}_{XX}|\right)
# -
# \frac{1}{2}\ln\left((2\pi e)^n|\boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}|\right).
# $
# $\displaystyle
# \text{Using } \ln A - \ln B = \ln\left(\frac{A}{B}\right),
# \text{ the constants cancel:}
# $
# $\displaystyle
# I(\mathbf{X};\mathbf{Y})
# =
# \frac{1}{2}\ln\left(
# \frac{|\boldsymbol{\Sigma}_{XX}|}{|\boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}|}
# \right).
# $
# $\displaystyle
# \boldsymbol{\Sigma}_{\mathbf{X}\mid \mathbf{Y}}
# =
# \boldsymbol{\Sigma}_{XX}
# -
# \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}.
# $
# $\displaystyle
# \text{Final form:}
# $
# $\displaystyle
# ...

# %% [markdown]
# 7.NUMERICAL DEMONSTRATION

# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# 1. Define Parameters
mu = np.array([0, 0])
# Positive correlation (Sigma_xy = 0.7)
sigma = np.array([[1.0, 0.7],
                  [0.7, 1.0]])

# Generate Samples
n_samples = 5000
data = np.random.multivariate_normal(mu, sigma, n_samples)
x_samples, y_samples = data[:, 0], data[:, 1]

# 2. Calculate Theoretical Conditional Distribution P(X | Y = y_fixed)
y_fixed = 1.2
# Formulas derived earlier:
# mu_cond = mu_x + (sigma_xy / sigma_yy) * (y_fixed - mu_y)
# var_cond = sigma_xx - (sigma_xy**2 / sigma_yy)
mu_cond = mu[0] + (sigma[0, 1] / sigma[1, 1]) * (y_fixed - mu[1])
var_cond = sigma[0, 0] - (sigma[0, 1]**2 / sigma[1, 1])

# Generate conditional samples (filtering the joint data for points where Y is near y_fixed)
condition_mask = np.abs(y_samples - y_fixed) < 0.1
x_conditional_samples = x_samples[condition_mask]

# 3. Create Subplots
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=(
        "Joint Density P(X, Y)", "Marginal P(Y)",
        "Marginal P(X)", f"Conditional P(X | Y={y_fixed})"
    ),
    vertical_spacing=0.15,
    horizontal_spacing=0.1
)

# --- Joint Plot ---
fig.add_trace(go.Histogram2dContour(x=x_samples, y=y_samples, colorscale='Viridis', name="Joint"), row=1, col=1)
fig.add_hline(y=y_fixed, line_dash="dash", line_color="red", annotation_text="Slice for P(X|Y)", row=1, col=1)

# --- Marginal Y ---
fig.add_trace(go.Histogram(y=y_samples, name="Marginal Y", marker_color='blue', opacity=0.6), row=1, col=2)

# --- Marginal X ---
fig.add_trace(go.Histogram(x=x_samples, name="Marginal X", marker_color='green', opacity=0.6), row=2, col=1)

# --- Conditional X | Y ---
fig.add_trace(go.Histogram(x=x_conditional_samples, name="Cond X|Y", marker_color='red', opacity=0.7), row=2, col=2)

# Update Layout
fig.update_layout(
    height=800, width=900,
    title_text="Multivariate Normal: Joint, Marginal, and Conditional",
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from IPython.display import display, Math

display(Math(r'''
\textbf{The Joint Plot:}
\text{The "tilt" of the ellipse represents the correlation } \boldsymbol{\Sigma}_{XY}.
\text{ The red dashed line represents conditioning on a value of } Y.
'''))

display(Math(r'''
\textbf{The Marginals:}
\text{These are the Gaussian distributions }
N(\mu_x, \sigma_{xx}) \text{ and } N(\mu_y, \sigma_{yy}),
\text{ obtained by projecting the joint distribution onto each axis.}
'''))

display(Math(r'''
\textbf{The Conditional:}
\text{Because } X \text{ and } Y \text{ are correlated, observing a high } Y
\text{ shifts } \mathbb{E}[X|Y] \text{ to the right.}
'''))

display(Math(r'''
\textbf{Precision:}
\text{The conditional distribution is narrower (lower variance) than the marginal } X.
\text{ Hence } \boldsymbol{\Sigma}_{X|Y} < \boldsymbol{\Sigma}_{XX}.
'''))
# Out:
# $\displaystyle
# \textbf{The Joint Plot:}
# \text{The "tilt" of the ellipse represents the correlation } \boldsymbol{\Sigma}_{XY}.
# \text{ The red dashed line represents conditioning on a value of } Y.
# $
# $\displaystyle
# \textbf{The Marginals:}
# \text{These are the Gaussian distributions }
# N(\mu_x, \sigma_{xx}) \text{ and } N(\mu_y, \sigma_{yy}),
# \text{ obtained by projecting the joint distribution onto each axis.}
# $
# $\displaystyle
# \textbf{The Conditional:}
# \text{Because } X \text{ and } Y \text{ are correlated, observing a high } Y
# \text{ shifts } \mathbb{E}[X|Y] \text{ to the right.}
# $
# $\displaystyle
# \textbf{Precision:}
# \text{The conditional distribution is narrower (lower variance) than the marginal } X.
# \text{ Hence } \boldsymbol{\Sigma}_{X|Y} < \boldsymbol{\Sigma}_{XX}.
# $

# %% [markdown]
# Q03)

# %%
from IPython.display import display, Math

display(Math(r'''
\textbf{1. Joint Distribution of } (X,Y)
'''))

display(Math(r'''
X \sim \mathcal{N}(0,1), \quad Q \sim \mathcal{N}(0,4), \quad X \perp Q, \quad Y = X + Q
'''))

display(Math(r'''
E[Y] = 0,\quad \mathrm{Var}(Y)=1+4=5
'''))

display(Math(r'''
\mathrm{Cov}(X,Y)=E[X(X+Q)]=E[X^2]+E[XQ]=1+0=1
'''))

display(Math(r'''
\begin{pmatrix} X \\ Y \end{pmatrix}
\sim
\mathcal{N}
\left(
\begin{pmatrix} 0 \\ 0 \end{pmatrix},
\begin{pmatrix} 1 & 1 \\ 1 & 5 \end{pmatrix}
\right)
'''))

display(Math(r'''
\textbf{2. Information Geometry: } X \notin \sigma(Y)
'''))

display(Math(r'''
\text{There is no deterministic function } X=g(Y)
\text{ since many } (x,q)\text{ pairs produce the same } Y.
'''))

display(Math(r'''
\textbf{3. Conditional Expectation (MMSE Estimate)}
'''))

display(Math(r'''
\mathbb{E}[X|Y=y]
=
\frac{\mathrm{Cov}(X,Y)}{\mathrm{Var}(Y)}y
=
\frac{1}{5}y
'''))

display(Math(r'''
\mathbb{E}[X|Y]=0.2Y
'''))

display(Math(r'''
\textbf{4. Residual Analysis}
'''))

display(Math(r'''
Z = X - 0.2Y
'''))

display(Math(r'''
\mathrm{Cov}(Z,Y)=E[XY]-0.2E[Y^2]=1-0.2(5)=0
'''))

display(Math(r'''
\text{Residual is orthogonal to } Y.
'''))

display(Math(r'''
\textbf{5. Entropies}
'''))

display(Math(r'''
h(X)=\frac{1}{2}\ln(2\pi e)
'''))

display(Math(r'''
\sigma_{X|Y}^2 = 1 - \frac{1^2}{5} = 0.8
'''))

display(Math(r'''
h(X|Y)=\frac{1}{2}\ln(2\pi e \cdot 0.8)
'''))

display(Math(r'''
\textbf{6. Mutual Information}
'''))

display(Math(r'''
I(X;Y)=\frac{1}{2}\ln\left(\frac{1}{0.8}\right)=\frac{1}{2}\ln(1.25)\approx 0.1116
'''))

display(Math(r'''
\textbf{7. Interpretation}
'''))

display(Math(r'''
\text{Using } X=Y \text{ gives error } 4,\quad
\text{using } \mathbb{E}[X|Y]=0.2Y \text{ gives error } 0.8
'''))

display(Math(r'''
\text{The factor } 0.2 \text{ is a shrinkage effect due to noise dominance in } Q.
'''))
# Out:
# $\displaystyle
# \textbf{1. Joint Distribution of } (X,Y)
# $
# $\displaystyle
# X \sim \mathcal{N}(0,1), \quad Q \sim \mathcal{N}(0,4), \quad X \perp Q, \quad Y = X + Q
# $
# $\displaystyle
# E[Y] = 0,\quad \mathrm{Var}(Y)=1+4=5
# $
# $\displaystyle
# \mathrm{Cov}(X,Y)=E[X(X+Q)]=E[X^2]+E[XQ]=1+0=1
# $
# $\displaystyle
# \begin{pmatrix} X \\ Y \end{pmatrix}
# \sim
# \mathcal{N}
# \left(
# \begin{pmatrix} 0 \\ 0 \end{pmatrix},
# \begin{pmatrix} 1 & 1 \\ 1 & 5 \end{pmatrix}
# \right)
# $
# $\displaystyle
# \textbf{2. Information Geometry: } X \notin \sigma(Y)
# $
# $\displaystyle
# \text{There is no deterministic function } X=g(Y)
# \text{ since many } (x,q)\text{ pairs produce the same } Y.
# $
# $\displaystyle
# \textbf{3. Conditional Expectation (MMSE Estimate)}
# $
# $\displaystyle
# \mathbb{E}[X|Y=y]
# =
# \frac{\mathrm{Cov}(X,Y)}{\mathrm{Var}(Y)}y
# =
# \frac{1}{5}y
# $
# $\displaystyle
# \mathbb{E}[X|Y]=0.2Y
# $
# $\displaystyle
# \textbf{4. Residual Analysis}
# $
# ...

# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy.stats import multivariate_normal, norm

# --- 1. Parameters for the Spindle Problem ---
# X: Temperature ~ N(0, 1)
# Q: Torque ~ N(0, 4)
# Y: Power = X + Q => Y ~ N(0, 5)
mu_x, mu_y = 0, 0
var_x, var_q = 1, 4
var_y = var_x + var_q
cov_xy = var_x  # Cov(X, X+Q) = Var(X) = 1
rho = cov_xy / (np.sqrt(var_x) * np.sqrt(var_y))

# Shrinkage Factor (Gain)
k = cov_xy / var_y  # 1/5 = 0.2

# --- 2. Generate Data for Visualization ---
# Sample points to show the "Cloud" of data
np.random.seed(42)
n_samples = 1000
x_samples = np.random.normal(mu_x, np.sqrt(var_x), n_samples)
q_samples = np.random.normal(0, np.sqrt(var_q), n_samples)
y_samples = x_samples + q_samples
x_hat = k * y_samples  # E[X|Y]
residual = x_samples - x_hat

# Grids for Contours
x_grid = np.linspace(-4, 4, 200)
y_grid = np.linspace(-8, 8, 200)
X_m, Y_m = np.meshgrid(x_grid, y_grid)
pos = np.dstack((X_m, Y_m))
Z = multivariate_normal([mu_x, mu_y], [[var_x, cov_xy], [cov_xy, var_y]]).pdf(pos)

# --- 3. Create Simulation Plot ---
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=(
        "Joint Distribution: X vs Y<br><sup>The Line of Best Estimate (Shrinkage)</sup>",
        "Estimation Error (Residual) vs Y<br><sup>Visualizing the Orthogonality Principle</sup>"
    )
)

# --- LEFT PLOT: Joint X, Y and the Estimator ---
# Density Contour
fig.add_trace(go.Contour(
    x=x_grid, y=y_grid, z=Z, colorscale='Blues', showscale=False, opacity=0.6,
    hoverinfo='skip'
), row=1, col=1)

# Scatter of actual realizations
fig.add_trace(go.Scatter(
    x=x_samples, y=y_samples, mode='markers',
    marker=dict(color='rgba(0,0,0,0.1)', size=3),
    name="Realized (x, y)"
), row=1, col=1)

# The Best Estimate Line E[X|Y] = 0.2Y
y_line = np.linspace(-8, 8, 10)
fig.add_trace(go.Scatter(
    x=k * y_line, y=y_line,
    line=dict(color='Red', width=4),
    name="E[X|Y] = 0.2Y (Optimal)"
), row=1, col=1)

# The Naive Estimator Line X = Y
fig.add_trace(go.Scatter(
    x=y_line, y=y_line,
    line=dict(color='Black', width=2, dash='dash'),
    name="X = Y (Naive)"
), row=1, col=1)

# --- RIGHT PLOT: Orthogonality (Residual vs Y) ---
fig.add_trace(go.Scatter(
    x=y_samples, y=residual, mode='markers',
    marker=dict(color='Purple', opacity=0.4, size=4),
    name="Residual (X - 0.2Y)"
), row=1, col=2)

# Horizontal line at 0 to show no correlation
fig.add_trace(go.Scatter(
    x=y_line, y=np.zeros_like(y_line),
    line=dict(color='Black', width=2),
    name="Zero Mean Error"
), row=1, col=2)

# --- Layout and Styling ---
fig.update_layout(
    height=600,
    title_text="Spindle Motor Diagnostic Simulation: Extracting Signal from Noise",
    template="plotly_white",
    hovermode='x'
)

fig.update_xaxes(title_text="True Temperature (X)", row=1, col=1)
fig.update_yaxes(title_text="Observed Power (Y)", row=1, col=1)
fig.update_xaxes(title_text="Observed Power (Y)", row=1, col=2)
fig.update_yaxes(title_text="Residual Error (Z)", row=1, col=2)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from IPython.display import display, Math

display(Math(r'''
\textbf{1. Shrinkage Principle (Conservative Estimation)}
'''))

display(Math(r'''
\mathbb{E}[X|Y] = 0.2Y
'''))

display(Math(r'''
\text{Because noise } (\sigma_Q^2=4) \text{ dominates signal } (\sigma_X^2=1),
\text{ raw measurements } Y \text{ are heavily polluted.}
'''))

display(Math(r'''
\text{Shrinkage prevents false alarms by reducing overreaction to spikes in } Y.
'''))

display(Math(r'''
\textbf{Interpretation: } Y=5 \Rightarrow \mathbb{E}[X|Y]=1
'''))

display(Math(r'''
\textbf{2. Orthogonality Principle (MMSE Optimality)}
'''))

display(Math(r'''
Z = X - 0.2Y, \quad \mathrm{Cov}(Z,Y)=0
'''))

display(Math(r'''
\text{Residual error is uncorrelated with the observation, meaning all extractable information from } Y \text{ is used.}
'''))

display(Math(r'''
\text{This confirms the estimator achieves Minimum Mean Square Error (MMSE).}
'''))

display(Math(r'''
\textbf{3. Information Geometry}
'''))

display(Math(r'''
\text{Even if } Y \text{ is fixed, } X \text{ still has variance } 0.8.
'''))

display(Math(r'''
\text{This reflects irreducible uncertainty due to mapping } (X,Q)\in\mathbb{R}^2 \to Y\in\mathbb{R}.
'''))

display(Math(r'''
h(X|Y) \text{ quantifies this remaining "cloud thickness".}
'''))

display(Math(r'''
\textbf{4. Variance Reduction and Mutual Information}
'''))

display(Math(r'''
\mathrm{Var}(X)=1,\quad \mathrm{Var}(X|Y)=0.8
'''))

display(Math(r'''
I(X;Y)=0.1116 \text{ nats}
'''))

display(Math(r'''
\text{This represents a 20\% reduction in uncertainty.}
'''))

display(Math(r'''
\text{To increase } I(X;Y), \text{ one needs a different sensor, not just a better estimator.}
'''))

display(Math(r'''
\textbf{Summary Table}
'''))

display(Math(r'''
\begin{array}{|c|c|c|}
\hline
\text{Concept} & \text{Result} & \text{Interpretation} \\
\hline
\text{Shrinkage } (k=0.2) & \mathbb{E}[X|Y]=0.2Y & \text{Avoid overreacting to noise} \\
\text{Orthogonality} & \mathrm{Cov}(Z,Y)=0 & \text{No further information in } Y \\
\text{MSE} & 0.8 & \text{20\% error reduction} \\
\text{Entropy} & h(X|Y) & \text{Remaining uncertainty after sensing} \\
\hline
\end{array}
'''))
# Out:
# $\displaystyle
# \textbf{1. Shrinkage Principle (Conservative Estimation)}
# $
# $\displaystyle
# \mathbb{E}[X|Y] = 0.2Y
# $
# $\displaystyle
# \text{Because noise } (\sigma_Q^2=4) \text{ dominates signal } (\sigma_X^2=1),
# \text{ raw measurements } Y \text{ are heavily polluted.}
# $
# $\displaystyle
# \text{Shrinkage prevents false alarms by reducing overreaction to spikes in } Y.
# $
# $\displaystyle
# \textbf{Interpretation: } Y=5 \Rightarrow \mathbb{E}[X|Y]=1
# $
# $\displaystyle
# \textbf{2. Orthogonality Principle (MMSE Optimality)}
# $
# $\displaystyle
# Z = X - 0.2Y, \quad \mathrm{Cov}(Z,Y)=0
# $
# $\displaystyle
# \text{Residual error is uncorrelated with the observation, meaning all extractable information from } Y \text{ is used.}
# $
# $\displaystyle
# \text{This confirms the estimator achieves Minimum Mean Square Error (MMSE).}
# $
# $\displaystyle
# \textbf{3. Information Geometry}
# $
# $\displaystyle
# ...
